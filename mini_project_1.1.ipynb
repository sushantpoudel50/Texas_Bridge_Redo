# %% [markdown]
# <h2> Mini Project In Texas Bridges</h2>
# <h3> To Find that are only evaluated in 2023 but not in 2022</h3>

# %%
# !pip install matplotlib_map_utils
# !pip install numpy==1.25.0. 
# !pip install geopandas
# !pip install pandas
# !pip install scikit-learn
# Out:
# Requirement already satisfied: matplotlib_map_utils in c:\users\sushant\anaconda3\lib\site-packages (1.0.3)
# Requirement already satisfied: matplotlib>=3.9.0 in c:\users\sushant\anaconda3\lib\site-packages (from matplotlib_map_utils) (3.9.2)
# Requirement already satisfied: cartopy>=0.23.0 in c:\users\sushant\anaconda3\lib\site-packages (from matplotlib_map_utils) (0.23.0)
# Requirement already satisfied: numpy>=1.21 in c:\users\sushant\anaconda3\lib\site-packages (from cartopy>=0.23.0->matplotlib_map_utils) (1.26.4)
# Requirement already satisfied: shapely>=1.7 in c:\users\sushant\anaconda3\lib\site-packages (from cartopy>=0.23.0->matplotlib_map_utils) (2.0.6)
# Requirement already satisfied: packaging>=20 in c:\users\sushant\anaconda3\lib\site-packages (from cartopy>=0.23.0->matplotlib_map_utils) (23.2)
# Requirement already satisfied: pyshp>=2.3 in c:\users\sushant\anaconda3\lib\site-packages (from cartopy>=0.23.0->matplotlib_map_utils) (2.3.1)
# Requirement already satisfied: pyproj>=3.3.1 in c:\users\sushant\anaconda3\lib\site-packages (from cartopy>=0.23.0->matplotlib_map_utils) (3.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sushant\anaconda3\lib\site-packages (from matplotlib>=3.9.0->matplotlib_map_utils) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sushant\anaconda3\lib\site-packages (from matplotlib>=3.9.0->matplotlib_map_utils) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sushant\anaconda3\lib\site-packages (from matplotlib>=3.9.0->matplotlib_map_utils) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sushant\anaconda3\lib\site-packages (from matplotlib>=3.9.0->matplotlib_map_utils) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\sushant\anaconda3\lib\site-packages (from matplotlib>=3.9.0->matplotlib_map_utils) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sushant\anaconda3\lib\site-packages (from matplotlib>=3.9.0->matplotlib_map_utils) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sushant\anaconda3\lib\site-packages (from matplotlib>=3.9.0->matplotlib_map_utils) (2.9.0.post0)
# Requirement already satisfied: certifi in c:\users\sushant\anaconda3\lib\site-packages (from pyproj>=3.3.1->cartopy>=0.23.0->matplotlib_map_utils) (2024.6.2)
# Requirement already satisfied: six>=1.5 in c:\users\sushant\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.9.0->matplotlib_map_utils) (1.16.0)
# Collecting numpy==1.25.0.
#   Downloading numpy-1.25.0.tar.gz (10.4 MB)
#      ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#      --------------------------------------- 0.0/10.4 MB 262.6 kB/s eta 0:00:40
#      --------------------------------------- 0.1/10.4 MB 508.4 kB/s eta 0:00:21
#       --------------------------------------- 0.2/10.4 MB 1.0 MB/s eta 0:00:10
#      -- ------------------------------------- 0.7/10.4 MB 2.8 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.4/10.4 MB 5.0 MB/s eta 0:00:02
#      -------- ------------------------------- 2.1/10.4 MB 6.4 MB/s eta 0:00:02
#      ---------- ----------------------------- 2.6/10.4 MB 7.0 MB/s eta 0:00:02
#      ----------- ---------------------------- 3.0/10.4 MB 6.8 MB/s eta 0:00:02
#      ------------ --------------------------- 3.2/10.4 MB 6.9 MB/s eta 0:00:02
#      ------------- -------------------------- 3.5/10.4 MB 6.7 MB/s eta 0:00:02
#      -------------- ------------------------- 3.9/10.4 MB 6.7 MB/s eta 0:00:01
#      --------------- ------------------------ 4.1/10.4 MB 6.7 MB/s eta 0:00:01
#      ---------------- ----------------------- 4.4/10.4 MB 6.7 MB/s eta 0:00:01
#      ----------------- ---------------------- 4.5/10.4 MB 6.6 MB/s eta 0:00:01
#      ----------------- ---------------------- 4.5/10.4 MB 6.6 MB/s eta 0:00:01
#      ----------------- ---------------------- 4.5/10.4 MB 6.6 MB/s eta 0:00:01
#      ----------------- ---------------------- 4.5/10.4 MB 6.6 MB/s eta 0:00:01
#      ----------------- ---------------------- 4.5/10.4 MB 6.6 MB/s eta 0:00:01
#      ------------------- -------------------- 5.2/10.4 MB 5.4 MB/s eta 0:00:01
#      ---------------------- ----------------- 5.8/10.4 MB 5.8 MB/s eta 0:00:01
#      -------------------------- ------------- 6.8/10.4 MB 6.5 MB/s eta 0:00:01
#      --------------------------- ------------ 7.1/10.4 MB 6.5 MB/s eta 0:00:01
#      ---------------------------- ----------- 7.4/10.4 MB 6.6 MB/s eta 0:00:01
#      ----------------------------- ---------- 7.7/10.4 MB 6.5 MB/s eta 0:00:01
#      ------------------------------ --------- 8.0/10.4 MB 6.5 MB/s eta 0:00:01
#      ------------------------------- -------- 8.2/10.4 MB 6.4 MB/s eta 0:00:01
#      ------------------------------- -------- 8.2/10.4 MB 6.4 MB/s eta 0:00:01
#      ------------------------------- -------- 8.2/10.4 MB 6.4 MB/s eta 0:00:01
#      ------------------------------- -------- 8.2/10.4 MB 6.4 MB/s eta 0:00:01
#      ------------------------------- -------- 8.2/10.4 MB 6.4 MB/s eta 0:00:01
#      -------------------------------- ------- 8.5/10.4 MB 5.6 MB/s eta 0:00:01
#      -------------------------------------- - 10.1/10.4 MB 6.5 MB/s eta 0:00:01
#      ---------------------------------------  10.3/10.4 MB 7.1 MB/s eta 0:00:01
#      ---------------------------------------- 10.4/10.4 MB 7.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [33 lines of output]
#   Traceback (most recent call last):
#     File "C:\Users\Sushant\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#       main()
#     File "C:\Users\Sushant\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\Sushant\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 112, in get_requires_for_build_wheel
#       backend = _build_backend()
#                 ^^^^^^^^^^^^^^^^
#     File "C:\Users\Sushant\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 77, in _build_backend
#       obj = import_module(mod_path)
#             ^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\Sushant\anaconda3\Lib\importlib\__init__.py", line 90, in import_module
#       return _bootstrap._gcd_import(name[level:], package, level)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#     File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#     File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#     File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#     File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#     File "C:\Users\Sushant\AppData\Local\pip-build-env-yxs1qxdn\overlay\Lib\site-packages\setuptools\__init__.py", line 16, in <module>
#       import setuptools.version
#     File "C:\Users\Sushant\AppData\Local\pip-build-env-yxs1qxdn\overlay\Lib\site-packages\setuptools\version.py", line 1, in <module>
#       import pkg_resources
#     File "C:\Users\Sushant\AppData\Local\pip-build-env-yxs1qxdn\overlay\Lib\site-packages\pkg_resources\__init__.py", line 2172, in <module>
#       register_finder(pkgutil.ImpImporter, find_on_path)
#                       ^^^^^^^^^^^^^^^^^^^
#   AttributeError: module 'pkgutil' has no attribute 'ImpImporter'. Did you mean: 'zipimporter'?
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# Getting requirements to build wheel did not run successfully.
# exit code: 1
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Requirement already satisfied: geopandas in c:\users\sushant\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in c:\users\sushant\anaconda3\lib\site-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\sushant\anaconda3\lib\site-packages (from geopandas) (0.9.0)
# Requirement already satisfied: packaging in c:\users\sushant\anaconda3\lib\site-packages (from geopandas) (23.2)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\sushant\anaconda3\lib\site-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\sushant\anaconda3\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\sushant\anaconda3\lib\site-packages (from geopandas) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sushant\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sushant\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sushant\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: certifi in c:\users\sushant\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2024.6.2)
# Requirement already satisfied: six>=1.5 in c:\users\sushant\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Requirement already satisfied: pandas in c:\users\sushant\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sushant\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sushant\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sushant\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sushant\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\sushant\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\sushant\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\sushant\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\sushant\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\sushant\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sushant\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)

# %%
#Import libraries
import os #Operating System interactions
import pandas as pd #Panel Data - for working with tabular data
import geopandas as gp # for GIS analysis or Geo Processing
from shapely.geometry import Point #Allows you to vreate gpkg files from xy data
import numpy as np #Numerical Calc
from matplotlib import pyplot as plt 
import matplotlib_map_utils as mapu #Alias of Map Utils like 'plt' for plot. For North Arrow.

# %%
#Set the directories
path = 'C:/Users/Sushant/OneDrive - Lamar University/1st semester/GIS/Project/Mini Project 1/Trial 2'
os.chdir(path) #Change the directory to that path

# %%
fname1 = 'Texas_County_Boundaries_Detailed_-8171692547258718760.gpkg'
texas = gp.read_file(fname1)

# %%
crs = texas.crs
print("CRS:", crs)
# Out:
# CRS: EPSG:3857

# %%
# Reproject the data to WGS84 (EPSG:4326)
texas_wgs84 = texas.to_crs(epsg=4326)

# %%
crs = texas_wgs84.crs
print("CRS:", crs)
# Out:
# CRS: EPSG:4326

# %%
texas_wgs84.head()
# Out:
#    GID  CMPTRL_NBR    CNTY_NM      DIST_NM  DPS_NBR CNTY_FIPS  CNTY_NBR  \
# 0   29           7   Atascosa  San Antonio        7     48013         7
# 1   30         158  Matagorda       Yoakum      161     48321       158
# 2   31         120    Jackson       Yoakum      120     48239       121
# 3   32          62    De Witt       Yoakum       62     48123        62
# 4   33         247     Wilson  San Antonio      247     48493       247
#
#    DIST_NBR MSA1990 MSA2000 MSA2010                                GlobalID  \
# 0        15       Y       Y       Y  {5024B0A9-D5E0-4E6A-9655-10EA956E9CDF}
# 1        13       N       N       N  {561E01F6-DDE9-4BAD-89A3-C7F809943987}
# 2        13       N       Y       Y  {BE92BEA2-4DB2-451F-B104-947B967D9853}
# 3        13       N       N       N  {08CDBCF3-2214-4849-A1EF-97538C8CCFA7}
# 4        15       Y       Y       Y  {FCA032FD-BBCC-4A83-A205-489A5DA70038}
#
#                                             geometry
# 0  MULTIPOLYGON (((-98.25038 28.67505, -98.24387 ...
# 1  MULTIPOLYGON (((-95.84101 29.17299, -95.8411 2...
# 2  MULTIPOLYGON (((-96.36618 29.01247, -96.36787 ...
# 3  MULTIPOLYGON (((-97.24011 29.38455, -97.24587 ...
# 4  MULTIPOLYGON (((-98.13515 29.43866, -98.13517 ...

# %%
type(texas_wgs84)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
print(texas_wgs84.crs)
# Out:
# EPSG:4326

# %%
#Visualize the overlay result (you can customise this based on your needs)
fig = plt.figure()
ax1 = fig.add_subplot() #we have multiple layers being added, so when we have to plot multiple layers on the plot, we need to make sure all of them are plotted on the same axis.
texas_wgs84.plot (facecolor='white', edgecolor='black', ax=ax1) #ax=ax1 - overlaping axis. 
texas_wgs84.plot(ax=ax1, color='none', markersize=1)
mapu.north_arrow.north_arrow(ax=ax1, location='lower right', rotation={'degrees':0}) 
ax1.set_xlabel('Longitude (WGS 84)')
ax1.set_ylabel('Latitude (WGS 84)')
plt.grid()
plt.title ('Texas Map')
plt.show()

# %%
#Read the CSV files of bridge and keep them in a variable
df_2022 = pd.read_csv('Bridge_2022.csv')
df_2023 = pd.read_csv('Bridge_2023.csv')
# Out:
# C:\Users\Sushant\AppData\Local\ipykernel_15052\3282890474.py:2: DtypeWarning: Columns (102) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2022 = pd.read_csv('Bridge_2022.csv')
# C:\Users\Sushant\AppData\Local\ipykernel_15052\3282890474.py:3: DtypeWarning: Columns (102) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2023 = pd.read_csv('Bridge_2023.csv')

# %%
# Function to convert the 8-9 digit lat/lon to decimal degrees (DD)
def dms_to_dd(value):
    # Convert the value to a string to extract parts, and ensure it's positive for parsing
    value_str = str(abs(int(value)))  # Ensure the value is treated as an integer and absolute

    # Extract the seconds (last 4 digits), minutes (2 digits before that), and degrees (rest of the digits)
    seconds = int(value_str[-4:]) / 100  # Seconds are the last four digits, divided by 100
    minutes = int(value_str[-6:-4])      # Minutes are the two digits before the seconds
    degrees = int(value_str[:-6])        # Degrees are everything before the minutes

    # Convert DMS to Decimal Degrees (DD)
    dd = degrees + minutes / 60 + seconds / 3600 # seconds are already divided by 100 in upper section

    # Return the result as a negative if the original value was negative
    return -dd if value < 0 else dd

# %%
# Convert latitude and longitude columns to numeric, coerce errors to NaN
df_2022['LAT_016'] = pd.to_numeric(df_2022['LAT_016'], errors='coerce')
df_2022['LONG_017'] = pd.to_numeric(df_2022['LONG_017'], errors='coerce')

# Convert latitude and longitude columns to numeric, coerce errors to NaN
df_2023['LAT_016'] = pd.to_numeric(df_2023['LAT_016'], errors='coerce')
df_2023['LONG_017'] = pd.to_numeric(df_2023['LONG_017'], errors='coerce')

# Remove rows with NaN values in the latitude and longitude columns
df_2022 = df_2022.dropna(subset=['LAT_016', 'LONG_017'])
df_2023 = df_2023.dropna(subset=['LAT_016', 'LONG_017'])

# Apply the conversion function to the latitude and longitude columns for 2022
df_2022['LAT_016'] = df_2022['LAT_016'].apply(dms_to_dd)
df_2022['LONG_017'] = df_2022['LONG_017'].apply(lambda x: -dms_to_dd(x))  # Longitude is negative for the western hemisphere

# Apply the conversion function to the latitude and longitude columns for 2023
df_2023['LAT_016'] = df_2023['LAT_016'].apply(dms_to_dd)
df_2023['LONG_017'] = df_2023['LONG_017'].apply(lambda x: -dms_to_dd(x))  # Longitude is negative for the western hemisphere

# Print or save the updated DataFrame
print(df_2022[['LAT_016', 'LONG_017']])
print(df_2023[['LAT_016', 'LONG_017']])
# Out:
#          LAT_016    LONG_017
# 0      35.315839 -101.935450
# 1      29.605833  -94.458000
# 2      29.608167  -94.430333
# 3      29.614333  -94.544500
# 4      29.692500  -94.080167
# ...          ...         ...
# 42334  32.771111  -96.811650
# 42335  32.771917  -96.810233
# 42336  32.770811  -96.807433
# 42337  32.777161  -96.810997
# 42338  32.759139  -96.976119
#
# [42339 rows x 2 columns]
#          LAT_016    LONG_017
# 0      35.315839 -101.935450
# 1      29.605833  -94.458000
# 2      29.608167  -94.430333
# 3      29.614333  -94.544500
# 4      29.692500  -94.080167
# ...          ...         ...
# 38132  27.783853  -97.619453
# 38133  27.799836  -97.619381
# 38134  27.904692  -97.880942
# 38135  27.887408  -97.850358
# 38136  27.875600  -97.829600
#
# [38137 rows x 2 columns]

# %%
# Print or save the updated DataFrame 2022
print(df_2022[['LAT_016', 'LONG_017']])
type(df_2023)
# Print or save the updated DataFrame 2023
print(df_2023[['LAT_016', 'LONG_017',]])
type(df_2023)
# Out:
#          LAT_016    LONG_017
# 0      35.315839 -101.935450
# 1      29.605833  -94.458000
# 2      29.608167  -94.430333
# 3      29.614333  -94.544500
# 4      29.692500  -94.080167
# ...          ...         ...
# 42334  32.771111  -96.811650
# 42335  32.771917  -96.810233
# 42336  32.770811  -96.807433
# 42337  32.777161  -96.810997
# 42338  32.759139  -96.976119
#
# [42339 rows x 2 columns]
#          LAT_016    LONG_017
# 0      35.315839 -101.935450
# 1      29.605833  -94.458000
# 2      29.608167  -94.430333
# 3      29.614333  -94.544500
# 4      29.692500  -94.080167
# ...          ...         ...
# 38132  27.783853  -97.619453
# 38133  27.799836  -97.619381
# 38134  27.904692  -97.880942
# 38135  27.887408  -97.850358
# 38136  27.875600  -97.829600
#
# [38137 rows x 2 columns]
# pandas.core.frame.DataFrame

# %%
# Create a varaible to indentify the bridge according to their Structural Number
structure_2022 = df_2022['STRUCTURE_NUMBER_008']
structure_2023 = df_2023['STRUCTURE_NUMBER_008']

# %%
type(structure_2022)
# Out:
# pandas.core.series.Series

# %%
# Select the bridges that only evaluated in 2023 but not in 2022 in variable to observe if the code is ok.
new_bridges_2023 = structure_2023[~structure_2023.isin(structure_2022)]

# %%
print(new_bridges_2023)
# Out:
# 9        000021594-62610
# 115      010600AA2130001
# 584      010920004702684
# 585      010920004702685
# 586      010920004702686
#               ...
# 37942    161780010216219
# 37943    161780010216221
# 37944    161780010216223
# 37945    161780010216225
# 37946    161780010216227
# Name: STRUCTURE_NUMBER_008, Length: 777, dtype: object

# %%
#Create a new data frame to select only the bridges that only evaluated in 2023 but not in 2022
new_bridges_df = df_2023[df_2023['STRUCTURE_NUMBER_008'].isin(new_bridges_2023)]

# %%
type(new_bridges_df)
# Out:
# pandas.core.frame.DataFrame

# %%
print(new_bridges_df)
# Out:
#        STATE_CODE_001 STRUCTURE_NUMBER_008  RECORD_TYPE_005A  \
# 9                  48      000021594-62610                 1
# 115                48      010600AA2130001                 1
# 584                48      010920004702684                 1
# 585                48      010920004702685                 1
# 586                48      010920004702686                 1
# ...               ...                  ...               ...
# 37942              48      161780010216219                 1
# 37943              48      161780010216221                 1
# 37944              48      161780010216223                 1
# 37945              48      161780010216225                 1
# 37946              48      161780010216227                 1
#
#        ROUTE_PREFIX_005B  SERVICE_LEVEL_005C  ROUTE_NUMBER_005D  \
# 9                      6                   0                0.0
# 115                    4                   1             2130.0
# 584                    2                   1               75.0
# 585                    2                   1               75.0
# 586                    2                   1               75.0
# ...                  ...                 ...                ...
# 37942                  2                   1               77.0
# 37943                  2                   1               77.0
# 37944                  2                   1               77.0
# 37945                  2                   1               77.0
# 37946                  2                   1               77.0
#
#        DIRECTION_005E  HIGHWAY_DISTRICT_002  COUNTY_CODE_003  PLACE_CODE_004  \
# 9                   0                     2              203               0
# 115                 0                     1              119               0
# 584                 1                     1              181           39200
# 585                 3                     1              181           39200
# 586                 1                     1              181           39200
# ...               ...                   ...              ...             ...
# 37942               1                    16              355               0
# 37943               1                    16              355               0
# 37944               1                    16              355               0
# 37945               1                    16              355               0
# 37946               1                    16              355               0
#
#        ... BRIDGE_LEN_IND_112  SCOUR_CRITICAL_113 FUTURE_ADT_114  \
# 9      ...                  Y                   8           15.0
# 115    ...                  Y                   8            1.0
# 584    ...                  Y                   N        86550.0
# 585    ...                  Y                   N            1.0
# 586    ...                  Y                   N            1.0
# ...    ...                ...                 ...            ...
# 37942  ...                  Y                   N        30328.0
# 37943  ...                  Y                   6        30328.0
# 37944  ...                  Y                   N        30328.0
# 37945  ...                  Y                   N        30328.0
# 37946  ...                  Y                   N            1.0
#
#       YEAR_OF_FUTURE_ADT_115  MIN_NAV_CLR_MT_116  FED_AGENCY  SUBMITTED_BY  \
# 9                     2041.0                 NaN           Y          63.0
# 115                   1900.0                 NaN           N          48.0
# 584                   2050.0                 NaN           N          48.0
# 585                   1900.0                 NaN           N          48.0
# 586                   1900.0                 NaN           N          48.0
# ...                      ...                 ...         ...           ...
# 37942                 2040.0                 NaN           N          48.0
# 37943                 2040.0                 NaN           N          48.0
# 37944                 2040.0                 NaN           N          48.0
# 37945                 2040.0                 NaN           N          48.0
# 37946                 1900.0                 NaN           N          48.0
#
#        BRIDGE_CONDITION  LOWEST_RATING  DECK_AREA
# 9                     G            8.0     127.98
# 115                   G            9.0      97.60
# 584                   G            8.0    1404.48
# 585                   G            8.0    1367.52
# 586                   G            9.0   20821.26
# ...                 ...            ...        ...
# 37942                 G            8.0    1060.18
# 37943                 G            7.0    6972.30
# 37944                 G            8.0    1060.18
# 37945                 G            7.0    1152.90
# 37946                 G            7.0    1060.18
#
# [777 rows x 123 columns]

# %% [markdown]
# <h3> So we have 777 new Bridges that are evaluated in 2023 but not in 2022. Proceed further to map those bridges in texas map </h3>

# %%
# Save as a CSV file in the directory for further Use.
new_bridges_df.to_csv('new_bridges_2023.csv', index=False)

# %%
type(new_bridges_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Observe the values of Lat, Long are in correct order for the ploting.
latitude = new_bridges_df['LAT_016']
longitude = new_bridges_df['LONG_017']

# %%
#Print the Latitude and Longitude
print(latitude)
print(longitude)
# Out:
# 9        32.680500
# 115      33.371656
# 584      33.628550
# 585      33.628522
# 586      33.637911
#            ...
# 37942    27.690872
# 37943    27.680267
# 37944    27.672511
# 37945    27.659728
# 37946    27.655214
# Name: LAT_016, Length: 777, dtype: float64
# 9       -94.145833
# 115     -95.774397
# 584     -96.613514
# 585     -96.613681
# 586     -96.616428
#            ...
# 37942   -97.734608
# 37943   -97.738428
# 37944   -97.741194
# 37945   -97.750092
# 37946   -97.757883
# Name: LONG_017, Length: 777, dtype: float64

# %%
# Plot the texas map in WGS84 withou the bridges

fig = plt.figure()
ax1 = fig.add_subplot() #we have multiple layers being added, so when we have to plot multiple layers on the plot, we need to make sure all of them are plotted on the same axis.
texas_wgs84.plot (facecolor='white', edgecolor='black', ax=ax1) #ax=ax1 - overlaping axis. 
texas_wgs84.plot(ax=ax1, color='none', markersize=1)
mapu.north_arrow.north_arrow(ax=ax1, location='lower right', rotation={'degrees':0}) 
ax1.set_xlabel('Longitude (NAD83)')
ax1.set_ylabel('Latitude (NAD83)')
plt.grid()
plt.title('Texas MAP')
plt.show()

# %%
#Visualize the overlay resultx

fig = plt.figure()
ax1 = fig.add_subplot() #we have multiple layers being added, so when we have to plot multiple layers on the plot, we need to make sure all of them are plotted on the same axis.
texas_wgs84.plot (facecolor='white', edgecolor='black', ax=ax1) #ax=ax1 - overlaping axis. 
texas_wgs84.plot(ax=ax1, color='none', markersize=1)
plt.scatter(longitude, latitude, c='blue', marker='.', edgecolor='k', alpha=0.7, label='Bridge Locations')
mapu.north_arrow.north_arrow(ax=ax1, location='lower right', rotation={'degrees':0}) 
ax1.set_xlabel('Longitude (WGS 84)')
ax1.set_ylabel('Latitude (WGS 84)')
plt.grid()
plt.legend(['Bridges'], loc='upper right')
plt.savefig('bridge_2023_notin_2022', dpi=300, bbox_inches='tight')
plt.title('Bridge survey in 2023 not in 2022')
plt.show()
